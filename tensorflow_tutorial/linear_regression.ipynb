# %%
import numpy as np
import tensorflow as tf
import matplotlib
matplotlib.use('TKAgg')
from matplotlib import pyplot as plt
# Out:
# /home/hojoon/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# /home/hojoon/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
def generate_dataset():
    # data is generated by y = 2*x + e
    x_batch = np.linspace(-1, 1, 101)
    y_batch = 2 * x_batch + np.random.randn(*x_batch.shape) * 0.3
    
    return x_batch, y_batch

# %%
def linear_regression():
    x = tf.placeholder(tf.float32, shape = (None,), name = 'x') # None = dynamic size
    y = tf.placeholder(tf.float32, shape = (None,), name = 'y')
    
    with tf.variable_scope('lreg') as scope:
        w = tf.Variable(np.random.normal(), name = 'W')
        y_pred = tf.multiply(w, x)
        
        loss = tf.reduce_mean(tf.square(y_pred - y))
    
    return x, y, y_pred, loss

# %%
def run():
    x_batch, y_batch = generate_dataset()
    
    x, y, y_pred, loss = linear_regression() #initialize model
    optimizer = tf.train.GradientDescentOptimizer(0.1).minimize(loss)
    
    init = tf.global_variables_initializer()
    with tf.Session() as sess:
        sess.run(init)
        
        feed_dict = {x: x_batch, y: y_batch}
        for _ in range(20):
            loss_val, _ = sess.run([loss, optimizer], feed_dict)
            print('loss:',loss_val)

        y_pred_batch = sess.run(y_pred, {x: x_batch}) #prediction after training

# %%
run()
# Out:
# loss: 0.38465625
# loss: 0.3454238
# loss: 0.31134552
# loss: 0.28174433
# loss: 0.256032
# loss: 0.23369767
# loss: 0.21429753
# loss: 0.1974461
# loss: 0.18280856
# loss: 0.17009403
# loss: 0.15904987
# loss: 0.14945668
# loss: 0.14112376
# loss: 0.1338856
# loss: 0.12759836
# loss: 0.122137114
# loss: 0.117393345
# loss: 0.11327281
# loss: 0.1096936
# loss: 0.10658462
